# %% [markdown]
# <a href="https://colab.research.google.com/github/VanessaMorales1/Scraping/blob/main/webScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Pre Requisitos

# %%
# Instalación de las librerias o dependencias necesarias
# !pip install beautifulsoup4 requests pandas

# %%
# Load dependencies
import json # modulo para trabajar con archivos JSON
import requests # libreria para hacer peticiones HTTP
import pandas as pd # libreria para procesar datos, proporciona funciones para analíticas
from bs4 import BeautifulSoup as bs # Extraer información de paginas web

# %% [markdown]
# # 2. Funciones para procesamiento de los datos

# %%
# Función que convierte una lista de elementos en un dataframe de pandas
def rowsToDataFrame(rows):
    df = pd.DataFrame(rows[1:], columns=rows[0])
    return df

# %%
# Función para extraer los datos de una tabla HTML
def processTableData(tbl):
    rows = []
    for child in tbl.find('tbody').children: # itera los items internos de la tabla [<tr>]
        row = []
        for td in child: # itera los items internos de la tabla [<td>]
            try:
                item = td.text.replace('\n', '') # recupera el texto del elemento [<td>]
                if item:
                    row.append(item) # Agrega cada elemento de la fila
            except:
                continue
        if len(row) > 0:
            rows.append(row) # agrega todos los campos de una fila de la tabla
    # print(rows)
    return rows

# %%
# Función para exxtrar la data de la URL y procesar el contenido HTML
def processDataHTML(data):
    soup = bs(data['sections'][1]['text'], 'html.parser') # Recupera el item del JSON y lo convierte en contenido HTML
    tbl = soup.find_all('table')[0] # Recupera la tabla del contenido HTML
    # print(tbl.prettify())
    tblRows = processTableData(tbl) # Ejecuta la función apra porcesar el contenido de la Tabla
    return tblRows

# %% [markdown]
# # 3. Extracción de Información

# %%
# Read website
# r = requests.get('https://www.wikiwand.com/es/Anexo:Tabla_estadística_de_la_Copa_Mundial_de_Fútbol')
r = requests.get('https://www.wikiwand.com/mcs-api/es.wikipedia.org/v1/page/mobile-sections-remaining/Anexo%3APa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n')  # Recuperamos el contenido de la web
# print(r)
table = processDataHTML(json.loads(r.content)) # Formate el contenido en formato JSON
df = rowsToDataFrame(table) # ejecuta la funcion para recupera los datos de la tabla como dataframe de Pandas
df
# Out:
#        N.º                    País (o territorio dependiente)  \
# 0        1                                    China China[13]
# 1        2                                              India
# 2        3                                     Estados Unidos
# 3        4                                Indonesia Indonesia
# 4        5                                  Pakistán Pakistán
# ..     ...                                                ...
# 246    247   Islas Ultramarinas Menores de los Estados Unidos
# 247    248  Tierras Australes y Antárticas Francesas Tierr...
# 248    249                                Islas Pitcairn (RU)
# 249  Mundo                                      7 936 806 000
# 250     N°                    País (o territorio dependiente)
#
#     Proyecciónexponencialde lapoblaciónal1/7/2023[8]  Totalmun-dial(%)  \
# 0                                      1 414 782 000             17,83
# 1                                      1 396 559 000             17,60
# 2                                        334 687 000              4,22
# 3                                        279 154 000              3,52
# 4                                        243 550 000              3,07
# ..                                               ...               ...
# 246                                              100              0,00
# 247                                              100              0,00
# 248                                               50              0,00
# 249                                           100,00              1,13
# 250    Proyecciónexponencialde lapoblaciónal1/7/2023  Totalmun-dial(%)
#
#     Cambiomedioanual(%)[9]  Cambioabsolutoanualpromedio  \
# 0                     0,43                    6 104 000
# 1                     0,91                   12 741 000
# 2                     0,42                    1 407 000
# 3                     1,11                    3 086 000
# 4                     2,56                    6 243 000
# ..                     ...                          ...
# 246                  -4,96                            0
# 247                  -3,73                            0
# 248                  -0,41                            0
# 249             90 275 000                       100,00
# 250    Cambiomedioanual(%)  Cambioabsolutoanualpromedio
#
#      Cambiomedioabs.totalanual(%) Añosparaeven-tualdu-pli-ca-ción[10]  \
# 0                            6,76                                 161
# 1                           14,11                                  76
# 2                            1,56                                 165
# 3                            3,42                                  63
# 4                            6,92                                  27
# ..                            ...                                 ...
# 246                          0,00                                   -
# 247                          0,00                                   -
# 248                          0,00                                   -
# 249                            62                       8 076 495 000
# 250  Cambiomedioabs.totalanual(%)     Añosparaeven-tualdu-pli-ca-ción
#
#     Censo másreciente,últimaestimaciónoficial,proyecciónde la ONUo reloj depoblaciónnacional  \
# 0                                        1 411 750 000
# 1                                        1 392 329 000
# 2                                          335 944 000
# 3                                          271 350 000
# 4                                          241 499 431
# ..                                                 ...
# 246                                                190
# 247                                                170
# 248                                                 47
# 249                                         17/12/2023
# 250  Censo másreciente,últimaestimaciónoficial,proy...
#
#     Fechade estaúltimacifra depoblación enparticular(d/mm/aaaa)[11]  \
# 0                                           31/12/2022
# 1                                            1/03/2023
# 2                                           17/12/2023
# 3                                              12/2020
# 4                                            1/03/2023
# ..                                                 ...
# 246                                          1/04/2010
# 247                                          1/02/2000
# 248                                          1/07/2021
# 249                                                  R
# 250  Fechade estaúltimacifra depoblación enparticul...
#
#                   Tipo[12]  \
# 0                        E
# 1                        A
# 2                        R
# 3                        E
# 4                        C
# ..                     ...
# 246                      C
# 247                      C
# 248                      E
# 249  www.worldometers.info
# 250                   Tipo
#
#     Enlace o hipervínculo(usualmente de tipo oficial)de esta última cifra de población
# 0                                     www.stats.gov.cn
# 1                                    main.mohfw.gov.in
# 2                                       www.census.gov
# 3                                        www.bps.go.id
# 4                                       www.pbs.gov.pk
# ..                                                 ...
# 246                                   www.statoids.com
# 247                                   www.statoids.com
# 248                               www.visitpitcairn.pn
# 249                                               None
# 250  Enlace  o hipervínculo(usualmente de tipo ofic...
#
# [251 rows x 12 columns]

# %%
# Inspeccionamos el tipo de dato de cada variable
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 12 columns):
#  #   Column                                                                                    Non-Null Count  Dtype
# ---  ------                                                                                    --------------  -----
#  0   N.º                                                                                       251 non-null    object
#  1   País (o territorio dependiente)                                                           251 non-null    object
#  2   Proyecciónexponencialde lapoblaciónal1/7/2023[8]                                          251 non-null    object
#  3   Totalmun-dial(%)                                                                          251 non-null    object
#  4   Cambiomedioanual(%)[9]                                                                    251 non-null    object
#  5   Cambioabsolutoanualpromedio                                                               251 non-null    object
#  6   Cambiomedioabs.totalanual(%)                                                              251 non-null    object
#  7   Añosparaeven-tualdu-pli-ca-ción[10]                                                       251 non-null    object
#  8   Censo másreciente,últimaestimaciónoficial,proyecciónde la ONUo reloj depoblaciónnacional  251 non-null    object
#  9   Fechade estaúltimacifra depoblación enparticular(d/mm/aaaa)[11]                           251 non-null    object
#  10  Tipo[12]                                                                                  251 non-null    object
#  11  Enlace o hipervínculo(usualmente de tipo oficial)de esta última cifra de población        249 non-null    object
# dtypes: object(12)
# memory usage: 23.7+ KB

# %% [markdown]
# # 4. Almacenamiento de los datos

# %%
# Guardamos las datos extraidos como archivo CSV
# se puede aplcair otras opciones para guardar (Base de datos)
df.to_csv('statsWorldCup.csv')
